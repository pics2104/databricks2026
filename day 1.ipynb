# %%
spark

# %%
sales_df=spark.read.csv("/Volumes/ramcatalog/ramschema/ramvolume/superstore.csv",header=True,inferSchema=True)
display(df)

# %%
df.createOrReplaceTempView("sales")
spark.sql("select * from sales where country='Canada'").display()

# %%
df.write.saveAsTable("sales_prem")
spark.sql("select * from sales where country='Canada'").display()

# %%
df.write.mode("overwrite").saveAsTable("sales_perm")
spark.sql("select * from sales_perm where country='India'").display()

# %%
# %sql show tables

# %%
# %sql drop table sales_perm

# %%
# %sql show tables

# %%
from pyspark.sql.types import * 
empschema=StructType([StructField("Empno",IntegerType(),True),StructField("Employeename",StringType(),True),StructField("sal",IntegerType(),True)])

empdf=spark.read.csv("/Volumes/ramcatalog/ramschema/ramvolume/emp.csv",header=True,schema=empschema)
display(empdf)

# %%
sales_df.count()
sales_df.cache()
sales_df.count()
sales_df.unpersist()

# %%
# %sql show tables

# %%
# %sql desc formatted sales_prem;

# %%
# %sql 
select * from sales_prem

# %%
# %sql
UPDATE sales_prem
SET Discount = 9
WHERE id = 32298;

# %%
# %sql 
select * from sales_prem

# %%
# %sql 
delete from sales_prem where Country = "United States"

# %%
# %sql describe history sales_prem

# %%
# %sql
select count(*) from sales_prem

# %%
# %sql
create table sales_restored as select * from sales_prem version as of 2

# %%
# %sql
select * from sales_prem timestamp as of '2026-01-08T09:58:47.000+00:00'

# %%
# %sql show tables

# %%
# %sql describe formatted sales_prem
